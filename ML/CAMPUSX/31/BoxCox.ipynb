# %% [markdown]
# **BOX-COX TRANSFORM**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **YEO JOHNSON TRANFORM**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
