# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('emp.csv')

# %%
df.shape
# Out:
# (15, 11)

# %%
df.isnull().sum()
# Out:
# customer_id           0
# age                   0
# income                2
# credit_score          2
# loyalty_tier          0
# education             0
# employment_status     0
# preferred_category    0
# state                 0
# is_subscribed         0
# churn                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (11, 11)

# %%
df.isnull().sum()
# Out:
# customer_id           0
# age                   0
# income                0
# credit_score          0
# loyalty_tier          0
# education             0
# employment_status     0
# preferred_category    0
# state                 0
# is_subscribed         0
# churn                 0
# dtype: int64

# %%
df.head()
# Out:
#   customer_id  age    income  credit_score loyalty_tier    education  \
# 0    CUST_101   28   45000.0         650.0       Silver     Bachelor
# 1    CUST_102   45   82000.0         720.0         Gold       Master
# 2    CUST_103   19   12000.0         580.0       Bronze  High School
# 4    CUST_105   52  115000.0         780.0     Platinum    Doctorate
# 6    CUST_107   41   67000.0         610.0       Silver       Master
#
#   employment_status preferred_category state  is_subscribed  churn
# 0          Employed        Electronics    MH              1      0
# 1          Employed           Clothing    DL              1      0
# 2           Student        Electronics    UP              0      1
# 4     Self-Employed              Books    MH              1      0
# 6          Employed        Electronics    KA              1      0

# %%
df.sample(5)
# Out:
#    customer_id  age    income  credit_score loyalty_tier  education  \
# 12    CUST_113   31   52000.0         670.0       Silver   Bachelor
# 10    CUST_111   50  140000.0         810.0     Platinum  Doctorate
# 7     CUST_108   60   95000.0         740.0     Platinum     Master
# 1     CUST_102   45   82000.0         720.0         Gold     Master
# 4     CUST_105   52  115000.0         780.0     Platinum  Doctorate
#
#    employment_status preferred_category state  is_subscribed  churn
# 12          Employed        Electronics    TN              1      0
# 10          Employed     Home & Kitchen    DL              1      0
# 7            Retired     Home & Kitchen    TN              1      0
# 1           Employed           Clothing    DL              1      0
# 4      Self-Employed              Books    MH              1      0

# %%
df['education'].unique()
# Out:
# array(['Bachelor', 'Master', 'High School', 'Doctorate'], dtype=object)
