# %% [markdown]
# FEATURE ENGINEERING

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# 1.1 ADDRESS MISSING VALUES

# %% [markdown]
# 1.2 HANDLING CATEGORICAL VALUES![image.png](attachment:image.png)

# %% [markdown]
# 1.3 OUTLIER DETECTION![image.png](attachment:image.png)

# %% [markdown]
# 1.4 FEATURE SCALING![image.png](attachment:image.png)

# %% [markdown]
# 2. FEATURE CONSTRUCTION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. FEATURE SELECTION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. FEATURE EXTRACTION

# %% [markdown]
# ![image.png](attachment:image.png)
