# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# 1) HOW BIG IS DATA

# %%
df = pd.read_csv('train.csv')
df.shape
# Out:
# (891, 12)

# %% [markdown]
# 2) Are there any missing values

# %%
df.head()  #gives first 5 rows
df.sample(5) #gives 5 random rows from data
# Out:
#      PassengerId  Survived  Pclass  \
# 432          433         1       2
# 528          529         0       3
# 883          884         0       2
# 129          130         0       3
# 421          422         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 432  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
# 528                          Salonen, Mr. Johan Werner    male  39.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 129                                 Ekstrom, Mr. Johan    male  45.0      0
# 421                                Charters, Mr. David    male  21.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 432      0        SC/AH 3085  26.0000   NaN        S
# 528      0           3101296   7.9250   NaN        S
# 883      0  C.A./SOTON 34068  10.5000   NaN        S
# 129      0            347061   6.9750   NaN        S
# ...

# %% [markdown]
# 3) WHAT IS THE DATA TYPE OF COLS

# %%
df.info()
# FOR EXAMPLE HERE WE SEE AGE IS FLOAT WHEN IT COULD BE INTEGER AND SAVE SOME SPACE FOR THIS DATA IT IS NOT THAT IMPORTANT BUT LARGE DATA IT SAVES A GOOD AMT OF SPACE AND MODEL ALSO RUNS FASTER
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 4) ARE THERE ANY MISSING VALUES

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 5) HOW DOES THE DATA LOOK MATHEMATICALLY?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 6) ARE THERE ANY DUPLICATE VALUES?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 7) HOW IS THE CORRELATION BETWEEN COLUMNS?

# %%
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
