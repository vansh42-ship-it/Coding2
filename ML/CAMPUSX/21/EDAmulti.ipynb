# %% [markdown]
# **MULTIVARIENT ANALYSIS**

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
titanic = pd.read_csv('train.csv')
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')

# %%
tips.sample(5)
# flights.tail(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 66        16.45  2.47  Female     No   Sat  Dinner     2
# 78        22.76  3.00    Male     No  Thur   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 153       24.55  2.00    Male     No   Sun  Dinner     4

# %% [markdown]
# 1. SCATTERPLOT(NUMERICAL-NUMERICAL)

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'])
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=df['sex'],style=df['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# 2. BAR-PLOT(Numerical-Categorial)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x=titanic['Pclass'],y=titanic['Age'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# 3. Box Plot(Numerical-Categorical)

# %%
sns.boxplot(x=titanic['Sex'],y=titanic['Age'],hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# 4. Distplot(Numerical-Categorical)

# %%
# sns.displot(titanic[titanic['Survived']==0]['Age'])
sns.displot(titanic[titanic['Survived']==1]['Age'])

# %% [markdown]
# 5. HeatMap(Categorial-Categorical)

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
pd.crosstab(titanic['Pclass'],titanic['Survived'])
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Pclass').mean(numeric_only=True)['Survived'] * 100
(titanic.groupby('Embarked').mean(numeric_only=True)['Survived'] * 100).plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# 6. ClusterMap(Categorical-Categorical)

# %%
pd.crosstab(titanic['SibSp'],titanic['Survived'])
sns.clustermap(pd.crosstab(titanic['SibSp'],titanic['Survived']))

# %% [markdown]
# Heatmap — just displays the data as-is. Rows and columns stay in whatever order your dataframe has them. You're just seeing the values as colors, nothing is rearranged. Good when the order of rows/columns matters (like time series, or Pclass 1/2/3 where order is meaningful).
#
# Clustermap — does everything a heatmap does, but also runs hierarchical clustering on your data and reorders rows and columns so that similar ones are grouped together. It also adds dendrograms (the tree diagrams on the sides) showing which rows/columns are most similar to each other. Good when you want to discover patterns — "which features tend to move together?"

# %% [markdown]
# 7. Pairplot

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')
# sns.pairplot(titanic)

# %% [markdown]
# 8. Lineplot (Numerical-Numerical)

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
new = flights.groupby('year').sum(numeric_only=True).reset_index()

# %%
sns.lineplot(x=new['year'],y=new['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# C:\Users\Vansh\AppData\Local\Temp\ipykernel_52200\265083589.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(values='passengers',index='month',columns='year')
# C:\Users\Vansh\AppData\Local\Temp\ipykernel_52200\265083589.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
